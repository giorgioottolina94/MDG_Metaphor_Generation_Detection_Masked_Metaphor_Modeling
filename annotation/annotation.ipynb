# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/My Drive/Colab Notebooks/experiments/stockholm/annotation
# Out:
# /content/drive/My Drive/Colab Notebooks/experiments/stockholm/annotation

# %%
import pandas as pd

# %%
system = pd.read_csv("system.csv", delimiter=';', skiprows=0, low_memory=False)

# %%
system.head()
# Out:
#                                             Sentence  ...  Source
# 0  Through the mixture of musical genres, new pop...  ...  system
# 1  For the good they comprehend not that the feeb...  ...  system
# 2  To fight their thirst and fever, by the shadow...  ...  system
# 3  Contemporary folk music reflects a genre gener...  ...  system
# 4                Filled the air with dreamy softness  ...  system
#
# [5 rows x 6 columns]

# %%
system.sort_values(
     by=["Fluency", "Meaning", "Creativity", "Metaphoricity"],
     ascending=False
 )[["Sentence", "Fluency", "Meaning", "Creativity", "Metaphoricity"]]
# Out:
#                                               Sentence  Fluency Meaning  \
# 18   Day by day his heart within him grew more satu...        5       5
# 19   Through the green lanes of the country, where ...        5       5
# 89   Love the wind among the branches, and the rain...        5       5
# 93   From the river came the warriors, clean and wa...        5       5
# 4                  Filled the air with dreamy softness        5       5
# 11   The genre exploded in the 1960s and 1970s, whe...        5       5
# 33   By the 1940s, magnetic audio tape encouraged m...        5       5
# 5    In 2019, the trap-inspired country/rap crossov...        5       5
# 26   The examples of Africa, Indonesia, and the Mid...        5       5
# 28   A more generalized description of nanotechnolo...        5       5
# 32   The modern Western music industry flourished b...        5       5
# 60   Due to its relatively open style, ambient musi...        5       5
# ...

# %%
human = pd.read_csv("human.csv", delimiter=';', skiprows=0, low_memory=False)

# %%
human.head()
# Out:
#                                             Sentence Fluency  ... Source Unnamed: 6
# 0     His credibility has been continuously attacked       3  ...  human        NaN
# 1   We have to drive innovation in our small country       2  ...  human        NaN
# 2  My incredibly full daily schedule always slips...       2  ...  human        NaN
# 3                   The comedian convulsed the crowd       3  ...  human        NaN
# 4  Headlines scream of pollution and dwindling na...       5  ...  human        NaN
#
# [5 rows x 7 columns]

# %%
human.sort_values(
     by=["Fluency", "Meaning", "Creativity", "Metaphoricity"],
     ascending=False
 )[["Sentence", "Fluency", "Meaning", "Creativity", "Metaphoricity"]]
# Out:
#                                               Sentence Fluency Meaning  \
# 4    Headlines scream of pollution and dwindling na...       5       5
# 6    Musical creativity really flowed inside that f...       5       5
# 48   This one scandal could very well sink his cand...       5       5
# 17                   The funding dried up a decade ago       5       5
# 7                    She stepped into a life of luxury       5       5
# 13   The economy sailed through the latest world re...       5       5
# 16            You must kick your addiction to the curb       5       5
# 54   The twentieth century saw intensive developmen...       5       5
# 11                              My laptop battery died       5       5
# 5    The Harry Potter saga has fed the imagination ...       5       4
# 10                Meteors blazed across the atmosphere       5       4
# 24   The president is simply letting money walk out...       4       5
# ...
